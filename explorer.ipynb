# %% [markdown]
# Conhecendo a requests
#
# - Primeira requisição

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
r
# Out:
# <Response [200]>

# %% [markdown]
# Explorando a biblioteca

# %%
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://api.github.com/events'

# %%
r.text
# Out:
# '[{"id":"34927169768","type":"PushEvent","actor":{"id":56163584,"login":"dandibot","display_login":"dandibot","gravatar_id":"","url":"https://api.github.com/users/dandibot","avatar_url":"https://avatars.githubusercontent.com/u/56163584?"},"repo":{"id":651646863,"name":"dandisets/000559","url":"https://api.github.com/repos/dandisets/000559"},"payload":{"repository_id":651646863,"push_id":16692805321,"size":2,"distinct_size":2,"ref":"refs/heads/git-annex","head":"849033687192a041d199221c30933b0b75fcd76d","before":"95a6f2ef6b7fd2661407d11bee80244067185668","commits":[{"sha":"f31b1b282730268a4685ea53b4a1c46c5b35373a","author":{"email":"team@dandiarchive.org","name":"DANDI Team"},"message":"update","distinct":true,"url":"https://api.github.com/repos/dandisets/000559/commits/f31b1b282730268a4685ea53b4a1c46c5b35373a"},{"sha":"849033687192a041d199221c30933b0b75fcd76d","author":{"email":"team@dandiarchive.org","name":"DANDI Team"},"message":"update","distinct":true,"url":"https://api.github.com/repos/dandisets/000559/commits/849033687192a041d199221c30933b0b75fcd76d"}]},"public":true,"created_at":"2024-01-18T12:02:59Z","org":{"id":56326858,"login":"dandisets","gravatar_id":"","url":"https://api.github.com/orgs/dandisets","avatar_url":"https://avatars.githubusercontent.com/u/56326858?"}},{"id":"34927169729","type":"PushEvent","actor":{"id":384954,"login":"tvsignal","display_login":"tvsignal","gravatar_id":"","url":"https://api.github.com/users/tvsignal","avatar_url":"https://avatars.githubusercontent.com/u/384954?"},"repo":{"id":417041535,"name":"navikt/pensjon-etterlatte-saksbehandling","url":"https://api.github.com/repos/navikt/pensjon-etterlatte-saksbehandling"},"payload":{"repository_id":417041535,"push_id":16692805300,"size":3,"distinct_size":3,"ref":"refs/heads/feature/oppdater-grunnlagsversjon-ved-bekreftelse-av-vilkaarsvurdering","head":"c743f09ec0de531d7fe7182066285db1bfb6541e","before":"349cd57c0d4999843e7bf8645fd0326c6842dc98","commits":[{"sha":"c3b09847d8e336c4b9c36371b6d3f405b8a21c8b","author":{"email":"71336041+madsop-nav@users.noreply.github.com","name":"Mads Opheim"},"message":"Rette informasjonsbrev til å bruke spesifisert mal frå river (#3456)\\n\\n* Opnar for å kunne eksplisitt sende inn brevkode når vi opprettar brev\\r\\n\\r\\n* Sender med brevkoden for informasjonsbrev vi opprettar automatisk, for å få rett mal\\r\\n\\r\\n* Forenklar litt med with\\r\\n\\r\\n* Oppdaterer test\\r\\n\\r\\n* Opnar for at brevkodar har fast tittel, og bruker han viss han fins\\r\\n\\r\\n* Parameternamn\\r\\n\\r\\n* Loggar litt meir","distinct":true,"url":"https://api.github.com/repos/navikt/pensjon-etterlatte-saksbehandling/commits/c3b09847d8e336c4b9c36371b6d3f405b8a21c8b"},{"sha":"1218fc3938cf5b3518da4ed8bfa0ba00f60fb6a2","author":{"email":"trond.valen@nav.no","name":"Trond Valen"},"message":"EY-3213: Viser differanse i trygdetids grunnlag bare hvis behandlingen er redigerbar.","distinct":true,"url":"https://api.github.com/repos/navikt/pensjon-etterlatte-saksbehandling/commits/1218fc3938cf5b3518da4ed8bfa0ba00f60fb6a2"},{"sha":"c743f09ec0de531d7fe7182066285db1bfb6541e","author":{"email":"trond.valen@nav.no","name":"Trond Valen"},"message":"EY-3213: Fullfører togglingen...","distinct":true,"url":"https://api.github.com/repos/navikt/pensjon-etterlatte-saksbehandling/commits/c743f09ec0de531d7fe7182066285db1bfb6541e"}]},"public":true,"created_at":"2024-01-18T12:02:59Z","org":{"id":11848947,"login":"navikt","gravatar_id":"","url":"https://api.github.com/orgs/navikt","avatar_url":"https://avatars.githubusercontent.com/u/11848947?"}},{"id":"34927169762","type":"IssueCommentEvent","actor":{"id":294737,"login":"gavinfaux","display_login":"gavinfaux","gravatar_id":"","url":"https://api.github.com/users/gavinfaux","avatar_url":"https://avatars.githubusercontent.com/u/294737?"},"repo":{"id":19441015,"name":"Shazwazza/Articulate","url":"https://api.github.com/repos/Shazwazza/Articulate"},"payload":{"action":"created","issue":{"url":"https://api.gith ...

# %%
r.json()
# Out:
# [{'id': '34927169768',
#   'type': 'PushEvent',
#   'actor': {'id': 56163584,
#    'login': 'dandibot',
#    'display_login': 'dandibot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dandibot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56163584?'},
#   'repo': {'id': 651646863,
#    'name': 'dandisets/000559',
#    'url': 'https://api.github.com/repos/dandisets/000559'},
#   'payload': {'repository_id': 651646863,
#    'push_id': 16692805321,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/git-annex',
#    'head': '849033687192a041d199221c30933b0b75fcd76d',
#    'before': '95a6f2ef6b7fd2661407d11bee80244067185668',
#    'commits': [{'sha': 'f31b1b282730268a4685ea53b4a1c46c5b35373a',
#      'author': {'email': 'team@dandiarchive.org', 'name': 'DANDI Team'},
#      'message': 'update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dandisets/000559/commits/f31b1b282730268a4685ea53b4a1c46c5b35373a'},
#     {'sha': '849033687192a041d199221c30933b0b75fcd76d',
#      'author': {'email': 'team@dandiarchive.org', 'name': 'DANDI Team'},
#      'message': 'update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dandisets/000559/commits/849033687192a041d199221c30933b0b75fcd76d'}]},
#   'public': True,
#   'created_at': '2024-01-18T12:02:59Z',
#   'org': {'id': 56326858,
#    'login': 'dandisets',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/dandisets',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56326858?'}},
#  {'id': '34927169729',
#   'type': 'PushEvent',
#   'actor': {'id': 384954,
#    'login': 'tvsignal',
#    'display_login': 'tvsignal',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tvsignal',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/384954?'},
#   'repo': {'id': 417041535,
#    'name': 'navikt/pensjon-etterlatte-saksbehandling',
#    'url': 'https://api.github.com/repos/navikt/pensjon-etterlatte-saksbehandling'},
#   'payload': {'repository_id': 417041535,
#    'push_id': 16692805300,
#    'size': 3,
#    'distinct_size': 3,
#    'ref': 'refs/heads/feature/oppdater-grunnlagsversjon-ved-bekreftelse-av-vilkaarsvurdering',
#    'head': 'c743f09ec0de531d7fe7182066285db1bfb6541e',
#    'before': '349cd57c0d4999843e7bf8645fd0326c6842dc98',
#    'commits': [{'sha': 'c3b09847d8e336c4b9c36371b6d3f405b8a21c8b',
#      'author': {'email': '71336041+madsop-nav@users.noreply.github.com',
#       'name': 'Mads Opheim'},
#      'message': 'Rette informasjonsbrev til å bruke spesifisert mal frå river (#3456)\n\n* Opnar for å kunne eksplisitt sende inn brevkode når vi opprettar brev\r\n\r\n* Sender med brevkoden for informasjonsbrev vi opprettar automatisk, for å få rett mal\r\n\r\n* Forenklar litt med with\r\n\r\n* Oppdaterer test\r\n\r\n* Opnar for at brevkodar har fast tittel, og bruker han viss han fins\r\n\r\n* Parameternamn\r\n\r\n* Loggar litt meir',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/navikt/pensjon-etterlatte-saksbehandling/commits/c3b09847d8e336c4b9c36371b6d3f405b8a21c8b'},
#     {'sha': '1218fc3938cf5b3518da4ed8bfa0ba00f60fb6a2',
#      'author': {'email': 'trond.valen@nav.no', 'name': 'Trond Valen'},
#      'message': 'EY-3213: Viser differanse i trygdetids grunnlag bare hvis behandlingen er redigerbar.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/navikt/pensjon-etterlatte-saksbehandling/commits/1218fc3938cf5b3518da4ed8bfa0ba00f60fb6a2'},
#     {'sha': 'c743f09ec0de531d7fe7182066285db1bfb6541e',
#      'author': {'email': 'trond.valen@nav.no', 'name': 'Trond Valen'},
#      'message': 'EY-3213: Fullfører togglingen...',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/navikt/pensjon-etterlatte-saksbehandling/commits/c743f09ec0de531d7fe7182066285db1bfb6541e'}]},
#   'public': True,
#   'created_at': '2024-01-18T12:02:59Z',
#   'org': {'id': 11848947,
#    'login': 'navikt',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/navikt',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11848947?'}},
#  {'id': '34927169762',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 294737,
#    'login': 'gavinfaux',
#    'display_login': 'gavinfaux',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gavinfaux',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/294737?'},
#   'repo': {'id': 19441015,
#    'name': 'Shazwazza/Articulate',
#    'url': 'https://api.github.com/repos/Shazwazza/Articulate'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/Shazwazza/Articulate/issues/439',
#     'repository_url': 'https://api.github.com/repos/Shazwazza/Articulate',
#     'labels_url': 'https://api.github.com/repos/Shazwazza/Articulate/issues/439/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/Shazwazza/Articulate/issues/439/comments',
#     'events_url': 'https://api.github.com/repos/Shazwazza/Articulate/issues/439/events',
#     'html_url': 'https://github.com/Shazwazza/Articulate/issues/439',
#     'id': 2082451458,
#     'node_id': 'I_kwDOASild858H7AC',
#     'number': 439,
#     'title': 'Articulate v5: Can filter articles by category or tag',
#     'user': {'login': 'khraibani',
#      'id': 4085627,
#      'node_id': 'MDQ6VXNlcjQwODU2Mjc=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/4085627?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/khraibani',
#      'html_url': 'https://github.com/khraibani',
#      'followers_url': 'https://api.github.com/users/khraibani/followers',
#      'following_url': 'https://api.github.com/users/khraibani/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/khraibani/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/khraibani/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/khraibani/subscriptions',
#      'organizations_url': 'https://api.github.com/users/khraibani/orgs',
#      'repos_url': 'https://api.github.com/users/khraibani/repos',
#      'events_url': 'https://api.github.com/users/khraibani/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/khraibani/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 97136269,
#       'node_id': 'MDU6TGFiZWw5NzEzNjI2OQ==',
#       'url': 'https://api.github.com/repos/Shazwazza/Articulate/labels/question',
#       'name': 'question',
#       'color': 'cc317c',
#       'default': True,
#       'description': None}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 9,
#     'created_at': '2024-01-15T17:35:50Z',
#     'updated_at': '2024-01-18T12:02:59Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': 'I am getting the following error when try to filter posts by tag or category, I get the same internal server error\r\n/blog/tags/ or /blog/categories/\r\n\r\n<img width="1801" alt="image" src="https://github.com/Shazwazza/Articulate/assets/4085627/7daac369-0afc-48bd-b73e-55532a324ce1">\r\n',
#     'reactions': {'url': 'https://api.github.com/repos/Shazwazza/Articulate/issues/439/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/Shazwazza/Articulate/issues/439/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/Shazwazza/Articulate/issues/comments/1898350152',
#     'html_url': 'https://github.com/Shazwazza/Articulate/issues/439#issuecomment-1898350152',
#     'issue_url': 'https://api.github.com/repos/Shazwazza/Articulate/issues/439',
#     'id': 1898350152,
#     'node_id': 'IC_kwDOASild85xJoZI',
#     'user': {'login': 'gavinfaux',
#      'id': 294737,
#      'node_id': 'MDQ6VXNlcjI5NDczNw==',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/294737?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/gavinfaux',
#      'html_url': 'https://github.com/gavinfaux',
#      'followers_url': 'https://api.github.com/users/gavinfaux/followers',
#      'following_url': 'https://api.github.com/users/gavinfaux/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/gavinfaux/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/gavinfaux/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/gavinfaux/subscriptions',
#      'organizations_url': 'https://api.github.com/users/gavinfaux/orgs',
#      'repos_url': 'https://api.github.com/users/gavinfaux/repos',
#      'events_url': 'https://api.github.com/users/gavinfaux/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/gavinfaux/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2024-01-18T12:02:57Z',
#     'updated_at': '2024-01-18T12:02:57Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': "@wvdweerd @Shazwazza  I'm seeing similar locally, due to the previous PR #436 which changed route priority, it's now too high and being skipped allowing not found handlers to kick in. \r\n\r\nWill try and figure out current route priorities and ensure correct order...",
#     'reactions': {'url': 'https://api.github.com/repos/Shazwazza/Articulate/issues/comments/1898350152/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2024-01-18T12:02:59Z'},
#  {'id': '34927169696',
#   'type': 'PushEvent',
#   'actor': {'id': 119787991,
#    'login': 'r4t1n',
#    'display_login': 'r4t1n',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/r4t1n',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/119787991?'},
#   'repo': {'id': 744519163,
#    'name': 'r4t1n/casaos-apps',
#    'url': 'https://api.github.com/repos/r4t1n/casaos-apps'},
#   'payload': {'repository_id': 744519163,
#    'push_id': 16692805292,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/main',
#    'head': '175194175478169057c166b11c5aa938c5ac69a9',
#    'before': '755767eb5ac9bfd07b05f7495bd81547994d3a51',
#    'commits': [{'sha': '721ba1a074a004259077052ded6e96c0f42e2eb1',
#      'author': {'email': 'r4t1n@proton.me', 'name': 'r4t1n'},
#      'message': 'Update script',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/r4t1n/casaos-apps/commits/721ba1a074a004259077052ded6e96c0f42e2eb1'},
#     {'sha': '175194175478169057c166b11c5aa938c5ac69a9',
#      'author': {'email': 'r4t1n@proton.me', 'name': 'r4t1n'},
#      'message': 'Structure script',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/r4t1n/casaos-apps/commits/175194175478169057c166b11c5aa938c5ac69a9'}]},
#   'public': True,
#   'created_at': '2024-01-18T12:02:59Z'},
#  {'id': '34927169708',
#   'type': 'PushEvent',
#   'actor': {'id': 34280393,
#    'login': 'aetchego',
#    'display_login': 'aetchego',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/aetchego',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34280393?'},
#   'repo': {'id': 309959670,
#    'name': 'aphp/Cohort360',
#    'url': 'https://api.github.com/repos/aphp/Cohort360'},
#   'payload': {'repository_id': 309959670,
#    'push_id': 16692805290,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/2201#save-filters-exploration',
#    'head': 'd224df1bf91f2b501bb283818292aab9414332d4',
#    'before': '79c1428cb0cf6ac4cc41c3f213274946351088d2',
#    'commits': [{'sha': '8f74a3cd58f4b052ffaf699aa2c97b5d4e471f1e',
#      'author': {'email': 'alizeetche@gmail.com', 'name': 'aetchego'},
#      'message': 'refacto name of PMSI criterias',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/aphp/Cohort360/commits/8f74a3cd58f4b052ffaf699aa2c97b5d4e471f1e'},
#     {'sha': 'd224df1bf91f2b501bb283818292aab9414332d4',
#      'author': {'email': 'alizeetche@gmail.com', 'name': 'aetchego'},
#      'message': 'savedFilters in all Ressources ( - final mapping)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/aphp/Cohort360/commits/d224df1bf91f2b501bb283818292aab9414332d4'}]},
#   'public': True,
#   'created_at': '2024-01-18T12:02:59Z',
#   'org': {'id': 26802401,
#    'login': 'aphp',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/aphp',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26802401?'}},
#  {'id': '34927169705',
#   'type': 'PushEvent',
#   'actor': {'id': 107480786,
#    'login': 'CccccccCieL',
#    'display_login': 'CccccccCieL',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/CccccccCieL',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/107480786?'},
#   'repo': {'id': 741367453,
#    'name': 'JasonWQD/Assignment-1-of-P-F',
#    'url': 'https://api.github.com/repos/JasonWQD/Assignment-1-of-P-F'},
#   'payload': {'repository_id': 741367453,
#    'push_id': 16692805287,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'b4e2c6e7992ea5544a6244d409b4e30a4832d8fa',
#    'before': '21dad7984e78f2ba8e665be8779123eaa35c797a',
#    'commits': [{'sha': 'b4e2c6e7992ea5544a6244d409b4e30a4832d8fa',
#      'author': {'email': '1799joker@gmail.com', 'name': 'CccccccCieL'},
#      'message': 'add iCheck',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JasonWQD/Assignment-1-of-P-F/commits/b4e2c6e7992ea5544a6244d409b4e30a4832d8fa'}]},
#   'public': True,
#   'created_at': '2024-01-18T12:02:59Z'},
#  {'id': '34927169678',
#   'type': 'PushEvent',
#   'actor': {'id': 100458176,
#    'login': 'nikitadevendran',
#    'display_login': 'nikitadevendran',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nikitadevendran',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/100458176?'},
#   'repo': {'id': 744826454,
#    'name': 'nikitadevendran/test8',
#    'url': 'https://api.github.com/repos/nikitadevendran/test8'},
#   'payload': {'repository_id': 744826454,
#    'push_id': 16692805271,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'ed54e2e851b9b1e3954827741d64ff933b434961',
#    'before': '92da2cc5f2583a586ffb1054aa4293d7fa5ee714',
#    'commits': [{'sha': 'ed54e2e851b9b1e3954827741d64ff933b434961',
#      'author': {'email': 'nikitadevendran@gmail.com', 'name': 'Nikita'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/nikitadevendran/test8/commits/ed54e2e851b9b1e3954827741d64ff933b434961'}]},
#   'public': True,
#   'created_at': '2024-01-18T12:02:59Z'},
#  {'id': '34927169650',
#   'type': 'PushEvent',
#   'actor': {'id': 156306869,
#    'login': 'aiccac',
#    'display_login': 'aiccac',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/aiccac',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/156306869?'},
#   'repo': {'id': 743489510,
#    'name': 'fadsgxch34/frtns1',
#    'url': 'https://api.github.com/repos/fadsgxch34/frtns1'},
#   'payload': {'repository_id': 743489510,
#    'push_id': 16692805257,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '845314b229049866c8a4373a7e766e14c116154e',
#    'before': '21e5c1f19c02f50ad40c4617ce236c9807e277bd',
#    'commits': [{'sha': '845314b229049866c8a4373a7e766e14c116154e',
#      'author': {'email': 'you@example.com', 'name': 'Your Name'},
#      'message': 'Empty Commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/fadsgxch34/frtns1/commits/845314b229049866c8a4373a7e766e14c116154e'}]},
#   'public': True,
#   'created_at': '2024-01-18T12:02:59Z',
#   'org': {'id': 156665272,
#    'login': 'fadsgxch34',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/fadsgxch34',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/156665272?'}},
#  {'id': '34927169718',
#   'type': 'PushEvent',
#   'actor': {'id': 74631596,
#    'login': 'AustinFairyland',
#    'display_login': 'AustinFairyland',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AustinFairyland',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/74631596?'},
#   'repo': {'id': 551542511,
#    'name': 'AustinFairyland/test_auto_push',
#    'url': 'https://api.github.com/repos/AustinFairyland/test_auto_push'},
#   'payload': {'repository_id': 551542511,
#    'push_id': 16692805304,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/ReleaseMaster',
#    'head': '0c1ee1d2857503a7944c33db40fa34860c586ab9',
#    'before': 'b7ad45ee7aa986bf8a2ec3daa9f00a481b8d1068',
#    'commits': [{'sha': '0c1ee1d2857503a7944c33db40fa34860c586ab9',
#      'author': {'email': 'fairylandhost@outlook.com',
#       'name': 'AustinFairyland'},
#      'message': 'add',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/AustinFairyland/test_auto_push/commits/0c1ee1d2857503a7944c33db40fa34860c586ab9'}]},
#   'public': True,
#   'created_at': '2024-01-18T12:02:59Z'},
#  {'id': '34927169711',
#   'type': 'PushEvent',
#   'actor': {'id': 156306931,
#    'login': 'azzelleb',
#    'display_login': 'azzelleb',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/azzelleb',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/156306931?'},
#   'repo': {'id': 744179031,
#    'name': 'azzelleb/Projcts5',
#    'url': 'https://api.github.com/repos/azzelleb/Projcts5'},
#   'payload': {'repository_id': 744179031,
#    'push_id': 16692805295,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'db367bdf96b6948f67f63c973c440c9006122f16',
#    'before': 'cf890b8c3318b73d20f04e9705411fe47a4d23a5',
#    'commits': [{'sha': 'db367bdf96b6948f67f63c973c440c9006122f16',
#      'author': {'email': 'you@example.com', 'name': 'Your Name'},
#      'message': 'Empty Commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/azzelleb/Projcts5/commits/db367bdf96b6948f67f63c973c440c9006122f16'}]},
#   'public': True,
#   'created_at': '2024-01-18T12:02:59Z'},
#  {'id': '34927169706',
#   'type': 'PushEvent',
#   'actor': {'id': 30083780,
#    'login': 'Faustasm',
#    'display_login': 'Faustasm',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Faustasm',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30083780?'},
#   'repo': {'id': 464457501,
#    'name': 'atviriduomenys/katalogas',
#    'url': 'https://api.github.com/repos/atviriduomenys/katalogas'},
#   'payload': {'repository_id': 464457501,
#    'push_id': 16692805272,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/fm_deploy_01_18',
#    'head': '0b5adefc655a2574e0a174395f3b525abdf548cc',
#    'before': '959baefb7edf361bb141e14363ff5eed00d698f7',
#    'commits': [{'sha': '0b5adefc655a2574e0a174395f3b525abdf548cc',
#      'author': {'email': 'faustasmail15@gmail.com', 'name': 'Faustas'},
#      'message': 'lock poetry file',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/atviriduomenys/katalogas/commits/0b5adefc655a2574e0a174395f3b525abdf548cc'}]},
#   'public': True,
#   'created_at': '2024-01-18T12:02:59Z',
#   'org': {'id': 10912052,
#    'login': 'atviriduomenys',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/atviriduomenys',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10912052?'}},
#  {'id': '34927169727',
#   'type': 'CreateEvent',
#   'actor': {'id': 112990084,
#    'login': 'danilevi12',
#    'display_login': 'danilevi12',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/danilevi12',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/112990084?'},
#   'repo': {'id': 744982315,
#    'name': 'danilevi12/mpo5000.pablojs.com',
#    'url': 'https://api.github.com/repos/danilevi12/mpo5000.pablojs.com'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-01-18T12:02:59Z'},
#  {'id': '34927169671',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 39814207,
#    'login': 'pull[bot]',
#    'display_login': 'pull',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pull[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39814207?'},
#   'repo': {'id': 421305392,
#    'name': 'CrazyForks/mybatis-3',
#    'url': 'https://api.github.com/repos/CrazyForks/mybatis-3'},
#   'payload': {'action': 'opened',
#    'number': 51,
#    'pull_request': {'url': 'https://api.github.com/repos/CrazyForks/mybatis-3/pulls/51',
#     'id': 1684721594,
#     'node_id': 'PR_kwDOGRycMM5kas-6',
#     'html_url': 'https://github.com/CrazyForks/mybatis-3/pull/51',
#     'diff_url': 'https://github.com/CrazyForks/mybatis-3/pull/51.diff',
#     'patch_url': 'https://github.com/CrazyForks/mybatis-3/pull/51.patch',
#     'issue_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/issues/51',
#     'number': 51,
#     'state': 'open',
#     'locked': False,
#     'title': '[pull] master from mybatis:master',
#     'user': {'login': 'pull[bot]',
#      'id': 39814207,
#      'node_id': 'MDM6Qm90Mzk4MTQyMDc=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/12910?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/pull%5Bbot%5D',
#      'html_url': 'https://github.com/apps/pull',
#      'followers_url': 'https://api.github.com/users/pull%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/pull%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/pull%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/pull%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/pull%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/pull%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/pull%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/pull%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/pull%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'See Commits and Changes for more details.\n\n-----\nCreated by [<img src="https://prod.download/pull-18h-svg" valign="bottom"/> **pull[bot]**](https://github.com/wei/pull)\n\n_Can you help keep this open source service alive? **[💖 Please sponsor : )](https://prod.download/pull-pr-sponsor)**_',
#     'created_at': '2024-01-18T12:02:58Z',
#     'updated_at': '2024-01-18T12:02:58Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': '86f6b0921a45225123ac18ceb93c52a9e4bb869e',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/pulls/51/commits',
#     'review_comments_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/pulls/51/comments',
#     'review_comment_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/issues/51/comments',
#     'statuses_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/statuses/d75595e395c97370cd14046261b030361c33b885',
#     'head': {'label': 'mybatis:master',
#      'ref': 'master',
#      'sha': 'd75595e395c97370cd14046261b030361c33b885',
#      'user': {'login': 'mybatis',
#       'id': 1483254,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE0ODMyNTQ=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/1483254?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/mybatis',
#       'html_url': 'https://github.com/mybatis',
#       'followers_url': 'https://api.github.com/users/mybatis/followers',
#       'following_url': 'https://api.github.com/users/mybatis/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/mybatis/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/mybatis/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/mybatis/subscriptions',
#       'organizations_url': 'https://api.github.com/users/mybatis/orgs',
#       'repos_url': 'https://api.github.com/users/mybatis/repos',
#       'events_url': 'https://api.github.com/users/mybatis/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/mybatis/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 8205602,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk4MjA1NjAy',
#       'name': 'mybatis-3',
#       'full_name': 'mybatis/mybatis-3',
#       'private': False,
#       'owner': {'login': 'mybatis',
#        'id': 1483254,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE0ODMyNTQ=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/1483254?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/mybatis',
#        'html_url': 'https://github.com/mybatis',
#        'followers_url': 'https://api.github.com/users/mybatis/followers',
#        'following_url': 'https://api.github.com/users/mybatis/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/mybatis/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/mybatis/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/mybatis/subscriptions',
#        'organizations_url': 'https://api.github.com/users/mybatis/orgs',
#        'repos_url': 'https://api.github.com/users/mybatis/repos',
#        'events_url': 'https://api.github.com/users/mybatis/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/mybatis/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/mybatis/mybatis-3',
#       'description': 'MyBatis SQL mapper framework for Java',
#       'fork': False,
#       'url': 'https://api.github.com/repos/mybatis/mybatis-3',
#       'forks_url': 'https://api.github.com/repos/mybatis/mybatis-3/forks',
#       'keys_url': 'https://api.github.com/repos/mybatis/mybatis-3/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/mybatis/mybatis-3/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/mybatis/mybatis-3/teams',
#       'hooks_url': 'https://api.github.com/repos/mybatis/mybatis-3/hooks',
#       'issue_events_url': 'https://api.github.com/repos/mybatis/mybatis-3/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/mybatis/mybatis-3/events',
#       'assignees_url': 'https://api.github.com/repos/mybatis/mybatis-3/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/mybatis/mybatis-3/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/mybatis/mybatis-3/tags',
#       'blobs_url': 'https://api.github.com/repos/mybatis/mybatis-3/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/mybatis/mybatis-3/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/mybatis/mybatis-3/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/mybatis/mybatis-3/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/mybatis/mybatis-3/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/mybatis/mybatis-3/languages',
#       'stargazers_url': 'https://api.github.com/repos/mybatis/mybatis-3/stargazers',
#       'contributors_url': 'https://api.github.com/repos/mybatis/mybatis-3/contributors',
#       'subscribers_url': 'https://api.github.com/repos/mybatis/mybatis-3/subscribers',
#       'subscription_url': 'https://api.github.com/repos/mybatis/mybatis-3/subscription',
#       'commits_url': 'https://api.github.com/repos/mybatis/mybatis-3/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/mybatis/mybatis-3/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/mybatis/mybatis-3/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/mybatis/mybatis-3/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/mybatis/mybatis-3/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/mybatis/mybatis-3/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/mybatis/mybatis-3/merges',
#       'archive_url': 'https://api.github.com/repos/mybatis/mybatis-3/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/mybatis/mybatis-3/downloads',
#       'issues_url': 'https://api.github.com/repos/mybatis/mybatis-3/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/mybatis/mybatis-3/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/mybatis/mybatis-3/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/mybatis/mybatis-3/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/mybatis/mybatis-3/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/mybatis/mybatis-3/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/mybatis/mybatis-3/deployments',
#       'created_at': '2013-02-14T19:03:32Z',
#       'updated_at': '2024-01-18T07:57:11Z',
#       'pushed_at': '2024-01-18T10:20:09Z',
#       'git_url': 'git://github.com/mybatis/mybatis-3.git',
#       'ssh_url': 'git@github.com:mybatis/mybatis-3.git',
#       'clone_url': 'https://github.com/mybatis/mybatis-3.git',
#       'svn_url': 'https://github.com/mybatis/mybatis-3',
#       'homepage': 'http://mybatis.github.io/mybatis-3/',
#       'size': 141710,
#       'stargazers_count': 19203,
#       'watchers_count': 19203,
#       'language': 'Java',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': True,
#       'has_discussions': True,
#       'forks_count': 12712,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 204,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': ['java', 'mybatis', 'sql'],
#       'visibility': 'public',
#       'forks': 12712,
#       'open_issues': 204,
#       'watchers': 19203,
#       'default_branch': 'master'}},
#     'base': {'label': 'CrazyForks:master',
#      'ref': 'master',
#      'sha': 'f07f887f0eb965dfa57c1ee427390fefa0403940',
#      'user': {'login': 'CrazyForks',
#       'id': 56880509,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU2ODgwNTA5',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/56880509?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/CrazyForks',
#       'html_url': 'https://github.com/CrazyForks',
#       'followers_url': 'https://api.github.com/users/CrazyForks/followers',
#       'following_url': 'https://api.github.com/users/CrazyForks/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/CrazyForks/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/CrazyForks/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/CrazyForks/subscriptions',
#       'organizations_url': 'https://api.github.com/users/CrazyForks/orgs',
#       'repos_url': 'https://api.github.com/users/CrazyForks/repos',
#       'events_url': 'https://api.github.com/users/CrazyForks/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/CrazyForks/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 421305392,
#       'node_id': 'R_kgDOGRycMA',
#       'name': 'mybatis-3',
#       'full_name': 'CrazyForks/mybatis-3',
#       'private': False,
#       'owner': {'login': 'CrazyForks',
#        'id': 56880509,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU2ODgwNTA5',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/56880509?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/CrazyForks',
#        'html_url': 'https://github.com/CrazyForks',
#        'followers_url': 'https://api.github.com/users/CrazyForks/followers',
#        'following_url': 'https://api.github.com/users/CrazyForks/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/CrazyForks/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/CrazyForks/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/CrazyForks/subscriptions',
#        'organizations_url': 'https://api.github.com/users/CrazyForks/orgs',
#        'repos_url': 'https://api.github.com/users/CrazyForks/repos',
#        'events_url': 'https://api.github.com/users/CrazyForks/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/CrazyForks/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/CrazyForks/mybatis-3',
#       'description': 'MyBatis SQL mapper framework for Java',
#       'fork': True,
#       'url': 'https://api.github.com/repos/CrazyForks/mybatis-3',
#       'forks_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/forks',
#       'keys_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/teams',
#       'hooks_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/hooks',
#       'issue_events_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/events',
#       'assignees_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/tags',
#       'blobs_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/languages',
#       'stargazers_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/stargazers',
#       'contributors_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/contributors',
#       'subscribers_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/subscribers',
#       'subscription_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/subscription',
#       'commits_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/merges',
#       'archive_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/downloads',
#       'issues_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/CrazyForks/mybatis-3/deployments',
#       'created_at': '2021-10-26T06:23:18Z',
#       'updated_at': '2021-12-19T04:20:24Z',
#       'pushed_at': '2024-01-18T12:02:58Z',
#       'git_url': 'git://github.com/CrazyForks/mybatis-3.git',
#       'ssh_url': 'git@github.com:CrazyForks/mybatis-3.git',
#       'clone_url': 'https://github.com/CrazyForks/mybatis-3.git',
#       'svn_url': 'https://github.com/CrazyForks/mybatis-3',
#       'homepage': 'http://mybatis.github.io/mybatis-3/',
#       'size': 114348,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Java',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/CrazyForks/mybatis-3/pulls/51'},
#      'html': {'href': 'https://github.com/CrazyForks/mybatis-3/pull/51'},
#      'issue': {'href': 'https://api.github.com/repos/CrazyForks/mybatis-3/issues/51'},
#      'comments': {'href': 'https://api.github.com/repos/CrazyForks/mybatis-3/issues/51/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/CrazyForks/mybatis-3/pulls/51/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/CrazyForks/mybatis-3/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/CrazyForks/mybatis-3/pulls/51/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/CrazyForks/mybatis-3/statuses/d75595e395c97370cd14046261b030361c33b885'}},
#     'author_association': 'NONE',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': True,
#     'mergeable_state': 'clean',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 4,
#     'additions': 2,
#     'deletions': 2,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2024-01-18T12:02:59Z',
#   'org': {'id': 56880509,
#    'login': 'CrazyForks',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/CrazyForks',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56880509?'}},
#  {'id': '34927169657',
#   'type': 'PushEvent',
#   'actor': {'id': 156306931,
#    'login': 'azzelleb',
#    'display_login': 'azzelleb',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/azzelleb',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/156306931?'},
#   'repo': {'id': 744178956,
#    'name': 'azzelleb/Projcts3',
#    'url': 'https://api.github.com/repos/azzelleb/Projcts3'},
#   'payload': {'repository_id': 744178956,
#    'push_id': 16692805267,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'fa1cb1f54cfdee03f71ff1566ff6f0f23ffac49a',
#    'before': 'e7c16b9fcbb1bd2abcd56e31ce8f387947b8c978',
#    'commits': [{'sha': 'fa1cb1f54cfdee03f71ff1566ff6f0f23ffac49a',
#      'author': {'email': 'you@example.com', 'name': 'Your Name'},
#      'message': 'Empty Commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/azzelleb/Projcts3/commits/fa1cb1f54cfdee03f71ff1566ff6f0f23ffac49a'}]},
#   'public': True,
#   'created_at': '2024-01-18T12:02:59Z'},
#  {'id': '34927169649',
#   'type': 'PushEvent',
#   'actor': {'id': 156306931,
#    'login': 'azzelleb',
#    'display_login': 'azzelleb',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/azzelleb',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/156306931?'},
#   'repo': {'id': 744179071,
#    'name': 'azzelleb/Projcts6',
#    'url': 'https://api.github.com/repos/azzelleb/Projcts6'},
#   'payload': {'repository_id': 744179071,
#    'push_id': 16692805250,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'abbfd23c5af88a72ed15dc51640a606179b3d267',
#    'before': '5877231e34889fa1416c492f0817a8016970cc8c',
#    'commits': [{'sha': 'abbfd23c5af88a72ed15dc51640a606179b3d267',
#      'author': {'email': 'you@example.com', 'name': 'Your Name'},
#      'message': 'Empty Commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/azzelleb/Projcts6/commits/abbfd23c5af88a72ed15dc51640a606179b3d267'}]},
#   'public': True,
#   'created_at': '2024-01-18T12:02:59Z'},
#  {'id': '34927169677',
#   'type': 'PushEvent',
#   'actor': {'id': 79488695,
#    'login': 'joung1010',
#    'display_login': 'joung1010',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/joung1010',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/79488695?'},
#   'repo': {'id': 708764904,
#    'name': 'joung1010/blog',
#    'url': 'https://api.github.com/repos/joung1010/blog'},
#   'payload': {'repository_id': 708764904,
#    'push_id': 16692805276,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'f23d3b5bc2ade12988cfda6c4f7b5c329baae252',
#    'before': 'eaf74d9bbcd174ff7523c326258edceccfad779f',
#    'commits': [{'sha': 'f23d3b5bc2ade12988cfda6c4f7b5c329baae252',
#      'author': {'email': 'joung4342@gmail.com', 'name': 'mason park'},
#      'message': '마크 다운 수정',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/joung1010/blog/commits/f23d3b5bc2ade12988cfda6c4f7b5c329baae252'}]},
#   'public': True,
#   'created_at': '2024-01-18T12:02:59Z'},
#  {'id': '34927169641',
#   'type': 'PushEvent',
#   'actor': {'id': 135054766,
#    'login': 'SRIRAM-SUDHA',
#    'display_login': 'SRIRAM-SUDHA',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SRIRAM-SUDHA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/135054766?'},
#   'repo': {'id': 744980799,
#    'name': 'SRIRAM-SUDHA/Digital-Clock',
#    'url': 'https://api.github.com/repos/SRIRAM-SUDHA/Digital-Clock'},
#   'payload': {'repository_id': 744980799,
#    'push_id': 16692805248,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '01d4319193dc3f4a708fe4b417a2d5a38a239f74',
#    'before': '740fa5a3f91ddf68a6a985679e7e80a5b584b5d3',
#    'commits': [{'sha': '01d4319193dc3f4a708fe4b417a2d5a38a239f74',
#      'author': {'email': '135054766+SRIRAM-SUDHA@users.noreply.github.com',
#       'name': 'SRIRAM-SUDHA'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/SRIRAM-SUDHA/Digital-Clock/commits/01d4319193dc3f4a708fe4b417a2d5a38a239f74'}]},
#   'public': True,
#   'created_at': '2024-01-18T12:02:59Z'},
#  {'id': '34927169670',
#   'type': 'PushEvent',
#   'actor': {'id': 111329684,
#    'login': 'B74LABgit',
#    'display_login': 'B74LABgit',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/B74LABgit',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/111329684?'},
#   'repo': {'id': 728366641,
#    'name': 'B74LABgit/CAM',
#    'url': 'https://api.github.com/repos/B74LABgit/CAM'},
#   'payload': {'repository_id': 728366641,
#    'push_id': 16692805260,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '79e66906c92ecee8480b2070bf751d21b0acdda5',
#    'before': '76c99f60259b1b2338cd08d9252986831093a20b',
#    'commits': [{'sha': '79e66906c92ecee8480b2070bf751d21b0acdda5',
#      'author': {'email': '111329684+B74LABgit@users.noreply.github.com',
#       'name': 'B74LABgit'},
#      'message': 'committing files',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/B74LABgit/CAM/commits/79e66906c92ecee8480b2070bf751d21b0acdda5'}]},
#   'public': True,
#   'created_at': '2024-01-18T12:02:59Z'},
#  {'id': '34927169594',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 393251501,
#    'name': 'nolim1t/btc-price-action-feed',
#    'url': 'https://api.github.com/repos/nolim1t/btc-price-action-feed'},
#   'payload': {'repository_id': 393251501,
#    'push_id': 16692805235,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '4aa372ab3cc0dc0e99828ca7cdbfdaeb92c62322',
#    'before': '88a39ea9040b82375a2bf79843e9049544a8fa5f',
#    'commits': [{'sha': '4aa372ab3cc0dc0e99828ca7cdbfdaeb92c62322',
#      'author': {'email': 'flat-data@users.noreply.github.com',
#       'name': 'flat-data'},
#      'message': 'Flat: latest data (2024-01-18T12:02:57.735Z)\n{\n  "date": "2024-01-18T12:02:57.735Z",\n  "files": [\n    {\n      "name": "coindesk-btc-price.json",\n      "deltaBytes": -1,\n      "source": "https://api.coindesk.com/v2/bpi/currentprice.json"\n    }\n  ]\n}',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/nolim1t/btc-price-action-feed/commits/4aa372ab3cc0dc0e99828ca7cdbfdaeb92c62322'}]},
#   'public': True,
#   'created_at': '2024-01-18T12:02:59Z'},
#  {'id': '34927169604',
#   'type': 'PushEvent',
#   'actor': {'id': 16629885,
#    'login': 'cnlkl',
#    'display_login': 'cnlkl',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cnlkl',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16629885?'},
#   'repo': {'id': 556528197,
#    'name': 'cnlkl/bk-repo',
#    'url': 'https://api.github.com/repos/cnlkl/bk-repo'},
#   'payload': {'repository_id': 556528197,
#    'push_id': 16692805241,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/issue_1626',
#    'head': '2c1b9a9488a0d598e566d66f29f7ba962279d68e',
#    'before': '54ff95ea2b21e45c627753f37b46f369f8add5e8',
#    'commits': [{'sha': '2c1b9a9488a0d598e566d66f29f7ba962279d68e',
#      'author': {'email': 'kunlongli@tencent.com', 'name': 'kunlongli'},
#      'message': 'feat: 增加CFS缓存命中率与访问时间间隔统计 #1626',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cnlkl/bk-repo/commits/2c1b9a9488a0d598e566d66f29f7ba962279d68e'}]},
#   'public': True,
#   'created_at': '2024-01-18T12:02:59Z'},
#  {'id': '34927169590',
#   'type': 'PushEvent',
#   'actor': {'id': 50820975,
#    'login': 'recepkaraca1',
#    'display_login': 'recepkaraca1',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/recepkaraca1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50820975?'},
#   'repo': {'id': 403618261,
#    'name': 'nitrid/piqoff',
#    'url': 'https://api.github.com/repos/nitrid/piqoff'},
#   'payload': {'repository_id': 403618261,
#    'push_id': 16692805237,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/customer-g2gourmet',
#    'head': '2ef9ed96e688212f41649975788aebb993322ea8',
#    'before': 'c1f443d15aeeeeab2c46be8b1b199cb88fc9d657',
#    'commits': [{'sha': '2ef9ed96e688212f41649975788aebb993322ea8',
#      'author': {'email': 'piqposfr@gmail.com', 'name': 'piqpos'},
#      'message': '.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/nitrid/piqoff/commits/2ef9ed96e688212f41649975788aebb993322ea8'}]},
#   'public': True,
#   'created_at': '2024-01-18T12:02:59Z'},
#  {'id': '34927169607',
#   'type': 'CreateEvent',
#   'actor': {'id': 157016054,
#    'login': 'veren123',
#    'display_login': 'veren123',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/veren123',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/157016054?'},
#   'repo': {'id': 744981297,
#    'name': 'veren123/tes',
#    'url': 'https://api.github.com/repos/veren123/tes'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-01-18T12:02:59Z'},
#  {'id': '34927169632',
#   'type': 'PushEvent',
#   'actor': {'id': 74361703,
#    'login': 'Sawthis',
#    'display_login': 'Sawthis',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Sawthis',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/74361703?'},
#   'repo': {'id': 551383783,
#    'name': 'Sawthis/test-infra',
#    'url': 'https://api.github.com/repos/Sawthis/test-infra'},
#   'payload': {'repository_id': 551383783,
#    'push_id': 16692805243,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/fix-opa-gatekeeper',
#    'head': '41857bf5fcd42e636e072165466132818872ab03',
#    'before': 'd2dcb360a47ffbba20eb35609a4fc15a32bd6483',
#    'commits': [{'sha': '41857bf5fcd42e636e072165466132818872ab03',
#      'author': {'email': 'wojciech.soltys@sap.com', 'name': 'Wojciech Soltys'},
#      'message': 'Remove duplicated images from sa-kyma-push-images OPA Gatekeeper config',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Sawthis/test-infra/commits/41857bf5fcd42e636e072165466132818872ab03'}]},
#   'public': True,
#   'created_at': '2024-01-18T12:02:59Z'},
#  {'id': '34927169602',
#   'type': 'PushEvent',
#   'actor': {'id': 153940760,
#    'login': 'mdmaid69',
#    'display_login': 'mdmaid69',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mdmaid69',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153940760?'},
#   'repo': {'id': 732717980,
#    'name': 'mdmaid69/reimagined-giggle',
#    'url': 'https://api.github.com/repos/mdmaid69/reimagined-giggle'},
#   'payload': {'repository_id': 732717980,
#    'push_id': 16692805232,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'ca32f3b4308f1c1c00a305ae4f2f85208fee0a01',
#    'before': '489a741b4f03ecf91ab975209c28852776383ac7',
#    'commits': [{'sha': 'ca32f3b4308f1c1c00a305ae4f2f85208fee0a01',
#      'author': {'email': 'robot@alexsyw.me', 'name': 'mdmaid69'},
#      'message': 'high traffic noise pretend land',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mdmaid69/reimagined-giggle/commits/ca32f3b4308f1c1c00a305ae4f2f85208fee0a01'}]},
#   'public': True,
#   'created_at': '2024-01-18T12:02:59Z'},
#  {'id': '34927169608',
#   'type': 'CreateEvent',
#   'actor': {'id': 73816044,
#    'login': 'realCallMeJ',
#    'display_login': 'realCallMeJ',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/realCallMeJ',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/73816044?'},
#   'repo': {'id': 744980514,
#    'name': 'realCallMeJ/txadmin-recipe',
#    'url': 'https://api.github.com/repos/realCallMeJ/txadmin-recipe'},
#   'payload': {'ref': 'main2',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-01-18T12:02:59Z'},
#  {'id': '34927169562',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 123719842,
#    'login': 'Piscabo',
#    'display_login': 'Piscabo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Piscabo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/123719842?'},
#   'repo': {'id': 710060245,
#    'name': 'phineas-pta/comfy-trt-test',
#    'url': 'https://api.github.com/repos/phineas-pta/comfy-trt-test'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/phineas-pta/comfy-trt-test/issues/5',
#     'repository_url': 'https://api.github.com/repos/phineas-pta/comfy-trt-test',
#     'labels_url': 'https://api.github.com/repos/phineas-pta/comfy-trt-test/issues/5/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/phineas-pta/comfy-trt-test/issues/5/comments',
#     'events_url': 'https://api.github.com/repos/phineas-pta/comfy-trt-test/issues/5/events',
#     'html_url': 'https://github.com/phineas-pta/comfy-trt-test/issues/5',
#     'id': 2079184275,
#     'node_id': 'I_kwDOKlKo1c577dWT',
#     'number': 5,
#     'title': 'Cannot Build the Unet Model -Help',
#     'user': {'login': 'Piscabo',
#      'id': 123719842,
#      'node_id': 'U_kgDOB1_Qog',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/123719842?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Piscabo',
#      'html_url': 'https://github.com/Piscabo',
#      'followers_url': 'https://api.github.com/users/Piscabo/followers',
#      'following_url': 'https://api.github.com/users/Piscabo/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Piscabo/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Piscabo/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Piscabo/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Piscabo/orgs',
#      'repos_url': 'https://api.github.com/users/Piscabo/repos',
#      'events_url': 'https://api.github.com/users/Piscabo/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Piscabo/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 6130192265,
#       'node_id': 'LA_kwDOKlKo1c8AAAABbWNPiQ',
#       'url': 'https://api.github.com/repos/phineas-pta/comfy-trt-test/labels/question',
#       'name': 'question',
#       'color': 'd876e3',
#       'default': True,
#       'description': 'Further information is requested'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 15,
#     'created_at': '2024-01-12T16:04:11Z',
#     'updated_at': '2024-01-18T12:02:59Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': '`python convert_unet.py --ckpt_path "H:\\ComfyUI\\models\\checkpoints\\SDXL\\turbovisionxlSuperFastXL_tvxlV431vae.safetensors" --batch_max 4 --height_min 512 --width_min 512 --height_max 1024 --width_max 1024 --token_count_max 300`\r\n\r\n warnings.warn(warning)\r\nERROR:root:Exporting to ONNX failed. ONNX export failed on an operator with unrecognized namespace xformers_flash::flash_fwd. If you are trying to export a custom operator, make sure you registered it with the right domain and version.\r\nBuilding TensorRT engine… This can take a while.\r\nBuilding TensorRT engine for H:\\ComfyUI\\custom_nodes\\comfy-trt-test\\comfy_trt\\Unet-onnx\\sd_xl_turbo_1.0_fp16.onnx: H:\\ComfyUI\\custom_nodes\\comfy-trt-test\\comfy_trt\\Unet-trt\\sd_xl_turbo_1.0_fp16_1a54828ff58cb83ba8972aa17e71bd66.trt\r\nCould not open file H:\\ComfyUI\\custom_nodes\\comfy-trt-test\\comfy_trt\\Unet-onnx\\sd_xl_turbo_1.0_fp16.onnx\r\nCould not open file H:\\ComfyUI\\custom_nodes\\comfy-trt-test\\comfy_trt\\Unet-onnx\\sd_xl_turbo_1.0_fp16.onnx\r\n[E] ModelImporter.cpp:773: Failed to parse ONNX model from file: H:\\ComfyUI\\custom_nodes\\comfy-trt-test\\comfy_trt\\Unet-onnx\\sd_xl_turbo_1.0_fp16.onnx\r\n[!] Failed to parse ONNX model. Does the model file exist and contain a valid ONNX model?',
#     'reactions': {'url': 'https://api.github.com/repos/phineas-pta/comfy-trt-test/issues/5/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/phineas-pta/comfy-trt-test/issues/5/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/phineas-pta/comfy-trt-test/issues/comments/1898350151',
#     'html_url': 'https://github.com/phineas-pta/comfy-trt-test/issues/5#issuecomment-1898350151',
#     'issue_url': 'https://api.github.com/repos/phineas-pta/comfy-trt-test/issues/5',
#     'id': 1898350151,
#     'node_id': 'IC_kwDOKlKo1c5xJoZH',
#     'user': {'login': 'Piscabo',
#      'id': 123719842,
#      'node_id': 'U_kgDOB1_Qog',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/123719842?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Piscabo',
#      'html_url': 'https://github.com/Piscabo',
#      'followers_url': 'https://api.github.com/users/Piscabo/followers',
#      'following_url': 'https://api.github.com/users/Piscabo/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Piscabo/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Piscabo/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Piscabo/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Piscabo/orgs',
#      'repos_url': 'https://api.github.com/users/Piscabo/repos',
#      'events_url': 'https://api.github.com/users/Piscabo/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Piscabo/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2024-01-18T12:02:57Z',
#     'updated_at': '2024-01-18T12:02:57Z',
#     'author_association': 'NONE',
#     'body': 'I removed xformers now I can create files, but they fail:\r\nBuilding TensorRT engine… This can take a while.\r\nBuilding TensorRT engine for C:\\AI_Files\\ComfyUI\\custom_nodes\\comfy-trt-test\\comfy_trt\\Unet-onnx\\sd_xl_base_1.0_0.9vae.onnx: C:\\AI_Files\\ComfyUI\\custom_nodes\\comfy-trt-test\\comfy_trt\\Unet-trt\\sd_xl_base_1.0_0.9vae_1a54828ff58cb83ba8972aa17e71bd66.trt\r\n**_[E] 1: [stdArchiveReader.cpp::nvinfer1::rt::StdArchiveReader::stdArchiveReaderInitCommon::47] Error Code 1: Serialization (Serialization assertion stdVersionRead == kSERIALIZATION_VERSION failed.Version tag does not match. Note: Current Version: 228, Serialized Engine Version: 224)\r\n[E] 4: The timing cache will not be used!\r\n[E] 1: [stdArchiveReader.cpp::nvinfer1::rt::StdArchiveReader::stdArchiveReaderInitCommon::47] Error Code 1: Serialization (Serialization assertion stdVersionRead == kSERIALIZATION_VERSION failed.Version tag does not match. Note: Current Version: 228, Serialized Engine Version: 224)\r\n[E] 4: The timing cache will not be used!_**\r\nTensorRT engines has been saved to disk.',
#     'reactions': {'url': 'https://api.github.com/repos/phineas-pta/comfy-trt-test/issues/comments/1898350151/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2024-01-18T12:02:59Z'},
#  {'id': '34927169603',
#   'type': 'CreateEvent',
#   'actor': {'id': 56189141,
#    'login': 'AlexanderStanevko',
#    'display_login': 'AlexanderStanevko',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AlexanderStanevko',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56189141?'},
#   'repo': {'id': 744798442,
#    'name': 'AlexanderStanevko/vue3-digital-ocean-deployment',
#    'url': 'https://api.github.com/repos/AlexanderStanevko/vue3-digital-ocean-deployment'},
#   'payload': {'ref': 'testbranch',
#    'ref_type': 'branch',
#    'master_branch': 'DEV',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-01-18T12:02:59Z'},
#  {'id': '34927169581',
#   'type': 'CreateEvent',
#   'actor': {'id': 92030096,
#    'login': 'checknurris',
#    'display_login': 'checknurris',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/checknurris',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/92030096?'},
#   'repo': {'id': 744982313,
#    'name': 'checknurris/finkraft-assignment',
#    'url': 'https://api.github.com/repos/checknurris/finkraft-assignment'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-01-18T12:02:59Z'},
#  {'id': '34927169599',
#   'type': 'CreateEvent',
#   'actor': {'id': 146030306,
#    'login': 'scxzyyy',
#    'display_login': 'scxzyyy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/scxzyyy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/146030306?'},
#   'repo': {'id': 744980087,
#    'name': 'scxzyyy/test',
#    'url': 'https://api.github.com/repos/scxzyyy/test'},
#   'payload': {'ref': 'new',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'тестовое описание репозитория',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-01-18T12:02:59Z'},
#  {'id': '34927169495',
#   'type': 'PushEvent',
#   'actor': {'id': 156306034,
#    'login': 'oss333ulf',
#    'display_login': 'oss333ulf',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/oss333ulf',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/156306034?'},
#   'repo': {'id': 742252389,
#    'name': 'oss333ulf/Projcts9',
#    'url': 'https://api.github.com/repos/oss333ulf/Projcts9'},
#   'payload': {'repository_id': 742252389,
#    'push_id': 16692805199,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '7824a0ba3ca86f2f815c790b348520da5b069d8e',
#    'before': '7c60db1b15c1afc4e18a58efc7b2c225d872a4fa',
#    'commits': [{'sha': '7824a0ba3ca86f2f815c790b348520da5b069d8e',
#      'author': {'email': 'you@example.com', 'name': 'Your Name'},
#      'message': 'Empty Commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/oss333ulf/Projcts9/commits/7824a0ba3ca86f2f815c790b348520da5b069d8e'}]},
#   'public': True,
#   'created_at': '2024-01-18T12:02:59Z'}]

# %% [markdown]
# Utilizando outro endpoint

# %%
r = requests.get('https://api.github.com/versions')
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# ['2022-11-28']

# %% [markdown]
# Extração de dados

# %%
headers = {'X-GitHub-Api-Version': '2022-11-28'}

# %%
api_base_url = 'https://api.github.com'
owner = 'amzn' # username de quem vamos extrair os dados
url = f'{api_base_url}/users/{owner}/repos'

# %%
url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
response = requests.get(url, headers=headers)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# [{'id': 171339259,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#   'name': '.github',
#   'full_name': 'amzn/.github',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/.github',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/.github',
#   'forks_url': 'https://api.github.com/repos/amzn/.github/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/.github/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/.github/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/.github/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/.github/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/.github/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/.github/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/.github/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/.github/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/.github/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/.github/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/.github/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/.github/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/.github/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/.github/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/.github/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/.github/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/.github/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/.github/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/.github/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/.github/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/.github/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/.github/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/.github/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/.github/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/.github/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/.github/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/.github/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/.github/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/.github/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/.github/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/.github/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/.github/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/.github/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/.github/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/.github/deployments',
#   'created_at': '2019-02-18T18:59:22Z',
#   'updated_at': '2024-01-02T14:58:32Z',
#   'pushed_at': '2023-11-28T09:44:26Z',
#   'git_url': 'git://github.com/amzn/.github.git',
#   'ssh_url': 'git@github.com:amzn/.github.git',
#   'clone_url': 'https://github.com/amzn/.github.git',
#   'svn_url': 'https://github.com/amzn/.github',
#   'homepage': None,
#   'size': 26,
#   'stargazers_count': 11,
#   'watchers_count': 11,
#   'language': None,
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 346,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 3,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 346,
#   'open_issues': 3,
#   'watchers': 11,
#   'default_branch': 'master'},
#  {'id': 492978607,
#   'node_id': 'R_kgDOHWJBrw',
#   'name': 'ads-advanced-tools-docs',
#   'full_name': 'amzn/ads-advanced-tools-docs',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#   'description': 'Code samples and supplements for the Amazon Ads advanced tools center',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs',
#   'forks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/deployments',
#   'created_at': '2022-05-16T19:49:03Z',
#   'updated_at': '2024-01-11T06:33:47Z',
#   'pushed_at': '2024-01-03T20:18:54Z',
#   'git_url': 'git://github.com/amzn/ads-advanced-tools-docs.git',
#   'ssh_url': 'git@github.com:amzn/ads-advanced-tools-docs.git',
#   'clone_url': 'https://github.com/amzn/ads-advanced-tools-docs.git',
#   'svn_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#   'homepage': 'https://advertising.amazon.com/API/docs/en-us/index',
#   'size': 1008,
#   'stargazers_count': 74,
#   'watchers_count': 74,
#   'language': None,
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': True,
#   'forks_count': 31,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 11,
#   'license': {'key': 'mit-0',
#    'name': 'MIT No Attribution',
#    'spdx_id': 'MIT-0',
#    'url': 'https://api.github.com/licenses/mit-0',
#    'node_id': 'MDc6TGljZW5zZTQx'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': ['amazon', 'amazon-ads-api', 'amazon-marketing-stream'],
#   'visibility': 'public',
#   'forks': 31,
#   'open_issues': 11,
#   'watchers': 74,
#   'default_branch': 'main'},
#  {'id': 674005216,
#   'node_id': 'R_kgDOKCyA4A',
#   'name': 'ads-pao-amznjs-gtm-template',
#   'full_name': 'amzn/ads-pao-amznjs-gtm-template',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template',
#   'forks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/deployments',
#   'created_at': '2023-08-02T23:41:56Z',
#   'updated_at': '2023-09-27T22:07:43Z',
#   'pushed_at': '2023-12-05T17:24:14Z',
#   'git_url': 'git://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#   'ssh_url': 'git@github.com:amzn/ads-pao-amznjs-gtm-template.git',
#   'clone_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#   'svn_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#   'homepage': None,
#   'size': 328,
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'Smarty',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 1,
#   'default_branch': 'main'},
#  {'id': 41117941,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk0MTExNzk0MQ==',
#   'name': 'alexa-coho',
#   'full_name': 'amzn/alexa-coho',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/alexa-coho',
#   'description': 'Sample code for building skill adapters for Alexa Connected Home using the Lighting API',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/alexa-coho',
#   'forks_url': 'https://api.github.com/repos/amzn/alexa-coho/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/alexa-coho/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/alexa-coho/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/alexa-coho/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/alexa-coho/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/alexa-coho/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/alexa-coho/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/alexa-coho/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/alexa-coho/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/alexa-coho/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/alexa-coho/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/alexa-coho/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/alexa-coho/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/alexa-coho/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/alexa-coho/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/alexa-coho/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/alexa-coho/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/alexa-coho/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/alexa-coho/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/alexa-coho/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/alexa-coho/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/alexa-coho/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/alexa-coho/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/alexa-coho/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/alexa-coho/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/alexa-coho/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/alexa-coho/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/alexa-coho/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/alexa-coho/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/alexa-coho/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/alexa-coho/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/alexa-coho/deployments',
#   'created_at': '2015-08-20T20:42:31Z',
#   'updated_at': '2023-12-19T17:38:03Z',
#   'pushed_at': '2023-04-01T08:35:29Z',
#   'git_url': 'git://github.com/amzn/alexa-coho.git',
#   'ssh_url': 'git@github.com:amzn/alexa-coho.git',
#   'clone_url': 'https://github.com/amzn/alexa-coho.git',
#   'svn_url': 'https://github.com/amzn/alexa-coho',
#   'homepage': None,
#   'size': 209,
#   'stargazers_count': 63,
#   'watchers_count': 63,
#   'language': 'JavaScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 25,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 4,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 25,
#   'open_issues': 4,
#   'watchers': 63,
#   'default_branch': 'master'},
#  {'id': 39471546,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzOTQ3MTU0Ng==',
#   'name': 'alexa-skills-kit-js',
#   'full_name': 'amzn/alexa-skills-kit-js',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/alexa-skills-kit-js',
#   'description': ' SDK and example code for building voice-enabled skills for the Amazon Echo. ',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js',
#   'forks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/deployments',
#   'created_at': '2015-07-21T21:46:48Z',
#   'updated_at': '2023-12-05T05:36:33Z',
#   'pushed_at': '2020-10-01T06:10:20Z',
#   'git_url': 'git://github.com/amzn/alexa-skills-kit-js.git',
#   'ssh_url': 'git@github.com:amzn/alexa-skills-kit-js.git',
#   'clone_url': 'https://github.com/amzn/alexa-skills-kit-js.git',
#   'svn_url': 'https://github.com/amzn/alexa-skills-kit-js',
#   'homepage': 'http://developer.amazon.com/ask',
#   'size': 8827,
#   'stargazers_count': 1132,
#   'watchers_count': 1132,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 1059,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 11,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 1059,
#   'open_issues': 11,
#   'watchers': 1132,
#   'default_branch': 'master'},
#  {'id': 495519526,
#   'node_id': 'R_kgDOHYkHJg',
#   'name': 'amazon-ads-advertiser-audience-normalization-sdk-py',
#   'full_name': 'amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/deployments',
#   'created_at': '2022-05-23T17:59:56Z',
#   'updated_at': '2024-01-10T17:03:31Z',
#   'pushed_at': '2022-05-23T21:20:34Z',
#   'git_url': 'git://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'ssh_url': 'git@github.com:amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'clone_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'svn_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'homepage': None,
#   'size': 16,
#   'stargazers_count': 6,
#   'watchers_count': 6,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 3,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'other',
#    'name': 'Other',
#    'spdx_id': 'NOASSERTION',
#    'url': None,
#    'node_id': 'MDc6TGljZW5zZTA='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 3,
#   'open_issues': 0,
#   'watchers': 6,
#   'default_branch': 'main'},
#  {'id': 61315875,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk2MTMxNTg3NQ==',
#   'name': 'amazon-advertising-api-php-sdk',
#   'full_name': 'amzn/amazon-advertising-api-php-sdk',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#   'description': '⛔️ DEPRECATED - Amazon Advertising API PHP Client Library',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/deployments',
#   'created_at': '2016-06-16T18:16:46Z',
#   'updated_at': '2023-11-28T05:56:05Z',
#   'pushed_at': '2020-09-20T17:25:48Z',
#   'git_url': 'git://github.com/amzn/amazon-advertising-api-php-sdk.git',
#   'ssh_url': 'git@github.com:amzn/amazon-advertising-api-php-sdk.git',
#   'clone_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk.git',
#   'svn_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#   'homepage': '',
#   'size': 49,
#   'stargazers_count': 93,
#   'watchers_count': 93,
#   'language': 'PHP',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 71,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 14,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 71,
#   'open_issues': 14,
#   'watchers': 93,
#   'default_branch': 'master'},
#  {'id': 429297502,
#   'node_id': 'R_kgDOGZaPXg',
#   'name': 'amazon-codeguru-profiler-for-spark',
#   'full_name': 'amzn/amazon-codeguru-profiler-for-spark',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark',
#   'description': 'A Spark plugin for CPU and memory profiling',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/deployments',
#   'created_at': '2021-11-18T04:37:55Z',
#   'updated_at': '2023-07-14T20:17:43Z',
#   'pushed_at': '2023-10-27T08:59:28Z',
#   'git_url': 'git://github.com/amzn/amazon-codeguru-profiler-for-spark.git',
#   'ssh_url': 'git@github.com:amzn/amazon-codeguru-profiler-for-spark.git',
#   'clone_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark.git',
#   'svn_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark',
#   'homepage': '',
#   'size': 2337,
#   'stargazers_count': 17,
#   'watchers_count': 17,
#   'language': 'Java',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 14,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 2,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 14,
#   'open_issues': 2,
#   'watchers': 17,
#   'default_branch': 'main'},
#  {'id': 397426400,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzOTc0MjY0MDA=',
#   'name': 'amazon-frustration-free-setup-certification-tool',
# ...
#   'url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/deployments',
#   'created_at': '2014-12-05T18:51:43Z',
#   'updated_at': '2023-07-13T19:38:54Z',
#   'pushed_at': '2023-07-30T04:40:47Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-sdk-java.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-sdk-java.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-sdk-java.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-sdk-java',
#   'homepage': 'https://pay.amazon.com/documentation',
#   'size': 13957,
#   'stargazers_count': 53,
#   'watchers_count': 53,
#   'language': 'Java',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 55,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 15,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 55,
#   'open_issues': 15,
#   'watchers': 53,
#   'default_branch': 'master'},
#  {'id': 26331269,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNjMzMTI2OQ==',
#   'name': 'amazon-pay-sdk-php',
#   'full_name': 'amzn/amazon-pay-sdk-php',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-pay-sdk-php',
#   'description': 'Amazon Pay PHP SDK',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/deployments',
#   'created_at': '2014-11-07T18:00:47Z',
#   'updated_at': '2023-12-05T23:09:28Z',
#   'pushed_at': '2023-05-17T10:12:31Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-sdk-php.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-sdk-php.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-sdk-php.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-sdk-php',
#   'homepage': 'https://pay.amazon.com/documentation',
#   'size': 866,
#   'stargazers_count': 208,
#   'watchers_count': 208,
#   'language': 'PHP',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 98,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 36,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 98,
#   'open_issues': 36,
#   'watchers': 208,
#   'default_branch': 'master'},
#  {'id': 29757348,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyOTc1NzM0OA==',
#   'name': 'amazon-pay-sdk-python',
#   'full_name': 'amzn/amazon-pay-sdk-python',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-pay-sdk-python',
#   'description': 'Amazon Pay Python SDK',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/deployments',
#   'created_at': '2015-01-23T23:00:34Z',
#   'updated_at': '2024-01-12T18:03:40Z',
#   'pushed_at': '2023-04-10T09:50:19Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-sdk-python.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-sdk-python.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-sdk-python.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-sdk-python',
#   'homepage': '',
#   'size': 83,
#   'stargazers_count': 52,
#   'watchers_count': 52,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 41,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 8,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 41,
#   'open_issues': 8,
#   'watchers': 52,
#   'default_branch': 'master'}]

# %%
len(response.json())
# Out:
# 30

# %% [markdown]
# Autenticação

# %%
access_token = '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'
headers = {'Authorization' : 'Bearer ' + access_token,
            'X-GitHub-Api-Version': '2022-11-28'}

# %% [markdown]
# Paginação

# %%
api_base_url = 'https://api.github.com'
owner = 'amzn' # username de quem vamos extrair os dados
url = f'{api_base_url}/users/{owner}/repos'
url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
repos_list = []

for num_page in range(1,6):
    try:
        url_page = f'{url}?page={num_page}'
        response = requests.get(url_page, headers=headers)
        repos_list.append(response.json())
    except:
        repos_list.append(None)

# %%
len(repos_list)
# Out:
# 5

# %%
len(repos_list[0])
# Out:
# 30

# %% [markdown]
# Nome dos repositórios

# %%
repos_list[0][1]['name']
# Out:
# 'ads-advanced-tools-docs'

# %%
repos_name = []
for page in repos_list:
    for repo in page:
        repos_name.append(repo['name'])
repos_name[:15]
# Out:
# ['.github',
#  'ads-advanced-tools-docs',
#  'ads-pao-amznjs-gtm-template',
#  'alexa-coho',
#  'alexa-skills-kit-js',
#  'amazon-ads-advertiser-audience-normalization-sdk-py',
#  'amazon-advertising-api-php-sdk',
#  'amazon-codeguru-profiler-for-spark',
#  'amazon-frustration-free-setup-certification-tool',
#  'amazon-hub-counter-api-docs',
#  'amazon-hub-counter-api-samples',
#  'amazon-hub-counter-sdk-java',
#  'amazon-hub-support',
#  'amazon-instant-access-sdk-java',
#  'amazon-instant-access-sdk-net']

# %%
len(repos_name)
# Out:
# 148

# %% [markdown]
# Linguagem do repositório

# %%
repos_list[1][1]['language']
# Out:
# 'PHP'

# %%
repos_language = []
for page in repos_list:
    for repo in page:
        repos_language.append(repo['language'])
repos_language[:15]
# Out:
# [None,
#  None,
#  'Smarty',
#  'JavaScript',
#  None,
#  'Python',
#  'PHP',
#  'Java',
#  'Python',
#  'CSS',
#  'Java',
#  'Java',
#  'PowerShell',
#  'Java',
#  'C#']

# %%
len(repos_language)
# Out:
# 148

# %% [markdown]
# Criando um DataFrame com Pandas

# %%
import pandas as pd

# %%
dados_amz = pd.DataFrame()
dados_amz['repository_name'] = repos_name
dados_amz['language'] = repos_language
dados_amz
# Out:
#                  repository_name    language
# 0                        .github        None
# 1        ads-advanced-tools-docs        None
# 2    ads-pao-amznjs-gtm-template      Smarty
# 3                     alexa-coho  JavaScript
# 4            alexa-skills-kit-js        None
# ..                           ...         ...
# 143             zeek-plugin-enip        Zeek
# 144         zeek-plugin-profinet        Zeek
# 145           zeek-plugin-s7comm        Zeek
# 146              zeek-plugin-tds        Zeek
# 147               zero-shot-rlhr      Python
#
# [148 rows x 2 columns]

# %% [markdown]
# Salvando o DataFrame

# %%
dados_amz.to_csv('amazon.csv')

# %% [markdown]
# Criando repositório com POST

# %%
api_base_url = 'https://api.github.com'
url = f'{api_base_url}/user/repos'

url
# Out:
# 'https://api.github.com/user/repos'

# %%
data = {
    'name': 'linguagens-utilizadas',
    'description': 'Repositorio com as linguagens utilizadas na Amazon, utilizando requests e pandas',
    'private': False
}

response = requests.post(url, json=data, headers=headers)
response.status_code
# Out:
# 201

# %% [markdown]
# Formato do arquivo

# %%
import base64

# %%
with open('amazon.csv', 'rb') as file:
    file_content = file.read()

encoded_content = base64.b64encode(file_content)

# %% [markdown]
# Upload do arquivo com PUT

# %%
api_base_url = 'https://api.github.com'
username = 'ChangCarlos'
repo = 'linguagens-utilizadas'
path = 'amazon.csv'

url = f'{api_base_url}/repos/{username}/{repo}/contents/{path}'
url
# Out:
# 'https://api.github.com/repos/ChangCarlos/linguagens-utilizadas/contents/amazon.csv'

# %%
data = {
    'message': 'Adicionando um novo arquivo no formato .csv',
    'content': encoded_content.decode('utf-8')
}

response = requests.put(url, json=data, headers=headers)
response.status_code
# Out:
# 422
